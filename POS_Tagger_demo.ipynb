# %% [markdown]
# # Welcome to pyiunstir!
#
# ### This notebook shows how to build a Part-of-Speech tagger using pyiunstir.
# ### This POS tagger takes advantage of the combinatorial nature of some parts of the iberian language (names, verbs, numbers) to tag the terms

# %%
import json

from pyiunstir.encoding import *
from pyiunstir.pos_tagger import POS_tagger

# Load the encodings
f_json = open('corpus/iberian.json', 'r')
symbols = json.load(f_json)
f_json.close()

# Load a collection of text written using the Northeastern script
f_json = open('corpus/NE_database.json', 'r')
corpus_NE = json.load(f_json)
f_json.close()

# Load a collection of text written using the Southeastern script
f_json = open('corpus/SE_database.json', 'r')
corpus_SE = json.load(f_json)
f_json.close()

# Load a collection of text written using the Greek Iberian script
f_json = open('corpus/GreekIberian_database.json', 'r')
corpus_GI = json.load(f_json)
f_json.close()

# %%
tagger = POS_tagger()

# %% [markdown]
# ## Let's find documents with the "kutu" particle. It is though to be related to letters (send a letter), alphabets (kutu = abc) and writing in general

# %%
for scp in corpus_NE:
    flag = 0
    if scp['support'] != 'coin':
        for t in scp['text_simplified']:
            if t.find('kutu') < 0:
                continue
            print ('===',t)
            for w in t.split(':'):
                w = standarize_word(w)
                print(w,tagger.tag_word(w))
# Out:
# === kutui
# kutui []
# === kutui
# kutui []
# === kutuka
# kutuka []
# === iŕe:bototaś:bitebakiŕś:bane:baŕenḿliki:antinḿlitu:tuŕane:aŕikaŕ:sekeniusu:atilebeiu:lauŕiskeŕkate:banḿliŕbai:tuŕane:kaisanḿliŕbai:tuŕane:itailiniŕe:kutur:biteŕoketetine:eŕatiaŕe:kokor:tauebartiate:aŕikaŕ:binḿlikise:iunstirlaku:bototaśeai:selkeai:bartuneai:unibeikeai:aneŕai:unibeikeai:iunstirlaku:uskeike:bototiki:keietisiatense:uśtalar:ilune:ban:ḿiŕ:eśu_lu:bitiŕoke:betense:uśkeaneŕ:lati
# ire []
# bototas []
# bitebakirs []
# bane [['Verb', ['bane', '', 'ban', 'e']]]
# marenaliki []
# antinalitu []
# turane []
# arikar []
# sekeniusu []
# atilebeiu []
# lauriskerkate [['Personal Name', ['lauriskerkate', 'lauriskerkate', 'laurisker', 'laur', 'isker', '?', '']]]
# banalirbai []
# turane []
# kaisanalirbai []
# turane []
# itailinire []
# kutur [['Name', ['kutur', 'kutur', '', ' letter/document']]]
# biteroketetine [['Verb', ['biteroketetine', 'bite', 'rok', 'etetine']]]
# eratiare []
# kokor []
# tauebartiate []
# arikar []
# binalikise []
# iunstirlaku []
# bototaseai []
# selkeai [['Personal Name', ['selkeai', 'selke', 'selke', 'selke', '', '', 'are']], ['Personal Name', ['selkeai', 'selkee', 'selke', 'selke', '', 'for', 'are']]]
# bartuneai []
# unibeikeai []
# anerai []
# unibeikeai []
# iunstirlaku []
# uskeike []
# bototiki []
# keietisiatense []
# ustalar []
# ilune [['Sim Personal Name', ['iltune', 'iltune', 'iltun', 'iltun', '', 'for', '']]]
# ban [['Verb', ['ban', '', 'ban', '']], ['Quantity', ['ban', 'ban', '', 'ban', '']]]
# nair []
# esu_lu []
# bitiroke [['Verb', ['bitiroke', 'biti', 'rok', 'e']]]
# betense []
# uskeaner []
# lati []
# === aŕeŕe:kututaike:bas:biteŕoketine:iŕika:
# arere []
# kututaike []
# bas [['Verb', ['bas', '', 'bas', '']]]
# biteroketine [['Verb', ['biteroketine', 'bite', 'rok', 'etine']]]
# irika []
#  []
# === ban:kutur:iŕaker
# ban [['Verb', ['ban', '', 'ban', '']], ['Quantity', ['ban', 'ban', '', 'ban', '']]]
# kutur [['Name', ['kutur', 'kutur', '', ' letter/document']]]
# iraker []
# === kutur:oisor
# kutur [['Name', ['kutur', 'kutur', '', ' letter/document']]]
# oisor []
# === _ḿbaŕe:kutur
# _umare [['Sim Verb', ['umare', '', 'umar', 'e']]]
# kutur [['Name', ['kutur', 'kutur', '', ' letter/document']]]
# === kutuñn:ḿbaŕ:bianer
# kutuñn []
# umar [['Verb', ['umar', '', 'umar', '']]]
# bianer [['Sim Verb', ['baner', '', 'ban', 'er']], ['Sim Verb', ['bibaner', 'bi', 'ban', 'er']]]
# === kutuki_
# kutuki_ []
# === koke:kutuŕ_
# koke []
# kutur_ [['Sim Name', ['kutur', 'kutur', '', ' letter/document']]]
# === kutuŕ:aŕ__e_
# kutur [['Name', ['kutur', 'kutur', '', ' letter/document']]]
# ar__e_ []
# === ortinkali:_sukasir:belenku:itaŕer:oŕtinkali:eśambe:tartiar:anbelsibems:kutun:tikirsatin
# ortinkali []
# _sukasir []
# belenku []
# itarer [['Verb', ['itarer', 'i', 'tar', 'er']]]
# ortinkali []
# esambe []
# tartiar [['Personal Name', ['tartiar', 'tartiar', 'tarti', 'tarti', '', 'for/from', '']]]
# anbelsibems []
# kutun []
# tikirsatin [['Personal Name', ['tikirsatin', 'tikirsatin', 'tikirsatin', 'tikirs', 'atin', '', '']]]
# === _n:iskutur:iteŕokeḿ:_
# _n []
# iskutur [['Name', ['iskutur', 'kutur', 'is', 'this letter/document']]]
# iterokena [['Verb', ['iterokena', 'ite', 'rok', 'ena']]]
# _ []
# === kutukiŕbitatikoukebosekoñḿ
# kutukirbitatikoukebosekoñna []
# === kukutultitibabitatatetekokototo_leśskaka__a_mniaŕbekikiuñḿ_
# kukutultitibabitatatetekokototo_lesskaka__a_mniarbekikiuñna_ []
# === kutukiŕbitatiko_stosaubooelñnḿite
# kutukirbitatiko_stosaubooelñnaite []
# === _itiatu:ban:kutur:biteŕokan
# _itiatu []
# ban [['Verb', ['ban', '', 'ban', '']], ['Quantity', ['ban', 'ban', '', 'ban', '']]]
# kutur [['Name', ['kutur', 'kutur', '', ' letter/document']]]
# biterokan [['Verb', ['biterokan', 'bite', 'rok', 'an']]]
# === kukutultitibabitata__koko______lbubeo__ŕkikitoto__mnḿbau
# kukutultitibabitata__koko______lbubeo__rkikitoto__mnumau []
# === kutukiŕbitatiko_
# kutukirbitatiko_ []

# %% [markdown]
# ## Now apply the same tagger to Southeastern texts (different encoding)

# %%
for scp in corpus_SE:
    flag = 0
    if scp['support'] != 'coin':
        for t in scp['text_simplified']:
            print ('===',t)
            for w in t.split(':'):
                w = standarize_word(w)
                print(w,tagger.tag_word(w))
# Out:
# === aitikeltunki:iunśtir:bekoŕ:śalbitas:teŕoketa:banotaŕan
# aitikeltunki []
# iunstir [['Verb', ['iunstir', 'i', 'unst', 'ir']]]
# bekor []
# salbitas []
# teroketa [['Sim Verb', ['teroketan', 'te', 'rok', 'etan']]]
# banotaran []
# === kobeśirekian
# kobesirekian []
# === kaŕesi_
# karesi_ []
# === iskeŕiar
# iskeriar [['Sim Personal Name', ['iskerir', 'iskerir', 'iskerir', 'isker', 'ir', '', '']], ['Sim Personal Name', ['iskerirar', 'iskerirar', 'iskerir', 'isker', 'ir', 'for/from', '']], ['Sim Personal Name', ['iskerar', 'iskerar', 'isker', 'isker', '', 'for/from', '']], ['Sim Name', ['iseriar', 'eriar', 'is', 'this pottery']]]
# === koniltiŕar:bitiar
# koniltirar [['Sim Personal Name', ['lakoniltirar', 'lakoniltirar', 'lakoniltir', 'lakon', 'iltir', 'for/from', '']], ['Sim Personal Name', ['bekoniltirar', 'bekoniltirar', 'bekoniltir', 'bekon', 'iltir', 'for/from', '']]]
# bitiar [['Sim Verb', ['bitar', 'bi', 'tar', '']], ['Sim Verb', ['bititar', 'biti', 'tar', '']]]
# === aituŕkin:bitiar
# aiturkin []
# bitiar [['Sim Verb', ['bitar', 'bi', 'tar', '']], ['Sim Verb', ['bititar', 'biti', 'tar', '']]]
# === aituŕkin:betiar
# aiturkin []
# betiar []
# === aibeŕon:ebaaŕen:betiar
# aiberon []
# ebaaren []
# betiar []
# === aibeloŕar:betiar
# aibelorar []
# betiar []
# === betiarinar
# betiarinar []
# === iltiŕtiker:bekebanin:kokar
# iltirtiker [['Personal Name', ['iltirtiker', 'iltirtiker', 'iltirtiker', 'iltir', 'tiker', '', '']]]
# bekebanin []
# kokar []
# === kokar
# kokar []
# === kaŕekaŕ
# karekar []
# === sekibekeŕ:lukeśir:akailtiŕtekeŕai:iŕ__ŕiatuiaś
# sekibeker []
# lukesir []
# akailtirtekerai [['Sim Personal Name', ['sakariltirtekeai', 'sakariltirte', 'sakariltir', 'sakar', 'iltir', 'ergative', 'are']], ['Sim Personal Name', ['sakailtirtekeai', 'sakailtirte', 'sakailtir', 'saka', 'iltir', 'ergative', 'are']], ['Sim Personal Name', ['sakailtiritekeai', 'sakailtirite', 'sakailtir', 'saka', 'iltir', '?', 'are']]]
# ir__riatuias []
# === balkeśire:anabeti:iuśtir:beles:kebelese__i:askeŕeŕtir:_ŕeka:kotua:teŕokekon
# balkesire [['Personal Name', ['balkesire', 'balkesire', 'balkesir', 'balkes', 'ir', 'for', '']]]
# anabeti [['Sim Personal Name', ['anarbeti', 'anarbeti', 'anarbeti', 'anar', 'beti', '', '']]]
# iustir [['Verb', ['iustir', 'i', 'ust', 'ir']]]
# beles [['Personal Name', ['beles', 'beles', 'beles', 'beles', '', '', '']]]
# kebelese__i []
# askerertir []
# _reka []
# kotua [['Name', ['kotua', 'kotua', '', ' letter/document']]]
# terokekon [['Sim Verb', ['terokkon', 'te', 'rok', 'kon']]]
# === ikoŕbaś:balkeŕei:ortituŕate
# ikorbas [['Personal Name', ['ikorbas', 'ikorbas', 'ikorbas', 'ikor', 'bas', '', '']]]
# balkerei []
# ortiturate []
# === kalteneite:ataukin
# kalteneite []
# ataukin []
# === beśkebeteŕsete:teia:baneia:basbetuŕbarten
# beskebetersete []
# teia []
# baneia [['Sim Quantity', ['banei', 'ban', '', 'ban', 'fraction']]]
# basbeturbarten []
# === ś_ŕlabi_n:kosbiteŕtuan:koika_skituŕ
# s_rlabi_n []
# kosbitertuan []
# koika_skitur []
# === ebarkoŕar
# ebarkorar []
# === _śelir:ututa:baśir:taŕakaŕ
# _selir []
# ututa []
# basir [['Verb', ['basir', '', 'bas', 'ir']]]
# tarakar []
# === otalaukitiker:sieltiŕikan
# otalaukitiker []
# sieltirikan []
# === euterer:sosintekerka:naiban
# euterer []
# sosintekerka [['Personal Name', ['sosintekerka', 'sosintekerka', 'sosinteker', 'sosin', 'teker', 'to recieve/give', '']]]
# naiban []
# === baneśaŕikan:etar
# banesarikan []
# etar [['Verb', ['etar', 'e', 'tar', '']], ['Name', ['etar', 'etar', '', ' bronze']]]
# === uŕketeikerka:e_ter:laki
# urketeikerka []
# e_ter []
# laki []
# === saltulakokia
# saltulakokia []
# === beŕśirka:aŕtakeŕka:koŕ_śtautinka:beŕśirka
# bersirka []
# artakerka []
# kor_stautinka []
# bersirka []
# === biuŕtakeŕka:__ltiŕka:saltulakokia:saltulakokia
# biurtakerka [['Sim Personal Name', ['biurkerka', 'biurkerka', 'biurker', 'biur', 'ker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtikerka', 'biurtikerka', 'biurtiker', 'biurti', 'ker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtarka', 'biurtarka', 'biurtar', 'biur', 'tar', 'to recieve/give', '']], ['Sim Personal Name', ['biurtikerka', 'biurtikerka', 'biurtiker', 'biur', 'tiker', 'to recieve/give', '']], ['Sim Personal Name', ['biurarkerka', 'biurarkerka', 'biurarker', 'biur', 'arker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtekerka', 'biurtekerka', 'biurteker', 'biur', 'teker', 'to recieve/give', '']], ['Sim Personal Name', ['biurlakerka', 'biurlakerka', 'biurlaker', 'biur', 'laker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtiarkerka', 'biurtiarkerka', 'biurtiarker', 'biurti', 'arker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtilakerka', 'biurtilakerka', 'biurtilaker', 'biurti', 'laker', 'to recieve/give', '']]]
# __ltirka []
# saltulakokia []
# saltulakokia []
# === kobeŕonka:beŕśirka:sakaŕbaśka:beŕśirka:aitukoŕkia
# koberonka []
# bersirka []
# sakarbaska [['Personal Name', ['sakarbaska', 'sakarbaska', 'sakarbas', 'sakar', 'bas', 'to recieve/give', '']]]
# bersirka []
# aitukorkia [['Sim Personal Name', ['aituikorka', 'aituikorka', 'aituikor', 'aitu', 'ikor', 'to recieve/give', '']]]
# === _nibeŕonka:biuŕiltiŕka:sikeŕka:biuŕtakeŕka:aitukoŕa
# _niberonka []
# biuriltirka [['Personal Name', ['biuriltirka', 'biuriltirka', 'biuriltir', 'biur', 'iltir', 'to recieve/give', '']]]
# sikerka [['Sim Personal Name', ['sikeirka', 'sikeirka', 'sikeir', 'sike', 'ir', 'to recieve/give', '']], ['Sim Personal Name', ['sikeka', 'sikeka', 'sike', 'sike', '', 'to recieve/give', '']]]
# biurtakerka [['Sim Personal Name', ['biurkerka', 'biurkerka', 'biurker', 'biur', 'ker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtikerka', 'biurtikerka', 'biurtiker', 'biurti', 'ker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtarka', 'biurtarka', 'biurtar', 'biur', 'tar', 'to recieve/give', '']], ['Sim Personal Name', ['biurtikerka', 'biurtikerka', 'biurtiker', 'biur', 'tiker', 'to recieve/give', '']], ['Sim Personal Name', ['biurarkerka', 'biurarkerka', 'biurarker', 'biur', 'arker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtekerka', 'biurtekerka', 'biurteker', 'biur', 'teker', 'to recieve/give', '']], ['Sim Personal Name', ['biurlakerka', 'biurlakerka', 'biurlaker', 'biur', 'laker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtiarkerka', 'biurtiarkerka', 'biurtiarker', 'biurti', 'arker', 'to recieve/give', '']], ['Sim Personal Name', ['biurtilakerka', 'biurtilakerka', 'biurtilaker', 'biurti', 'laker', 'to recieve/give', '']]]
# aitukora []

# %% [markdown]
# ### Finally, to writings in Greek Iberian

# %%
for scp in corpus_GI:
    flag = 0
    if scp['support'] != 'coin':
        for t in scp['text_simplified']:
            print ('===',t)
            for w in t.split(':'):
                w = standarize_word(w)
                print(w,tagger.tag_word(w))
# Out:
# === iŕike:orti:kaŕokan:tatula:baśk:buiśtiner:bakaŕok:sss:tuŕlbailuŕa:lekuśekik:baseŕokeiunbaita:uŕke:basbitiŕbartin:iŕike:baseŕokar:tebint:belakaśikauŕ:isbinai:askantis:takiskaŕok:binikebin:śalir:kitei:kaibikait
# irike []
# orti []
# karokan []
# tatula []
# bask []
# buistiner []
# bakarok []
# sss []
# turlbailura []
# lekusekik []
# baserokeiunbaita []
# urke []
# basbitirbartin []
# irike []
# baserokar []
# tebint []
# belakasikaur []
# isbinai []
# askantis []
# takiskarok []
# binikebin [['Sim Quantity', ['binkebin', 'binkebin', 'binke', 'bin', '']]]
# salir [['Name', ['salir', 'salir', '', ' money']]]
# kitei [['Name', ['kitei', 'kitei', '', ' silver']]]
# kaibikait []
# === sakaŕiskeŕar:nai
# sakariskerar [['Personal Name', ['sakariskerar', 'sakariskerar', 'sakarisker', 'sakar', 'isker', 'for/from', '']]]
# nai [['Verb', ['nai', 'n', 'ai', 'I am']]]
# === iunstir:śalirk:basiŕtiŕ:sabaŕitai:birinaŕ:kuŕś:boiśtinkiśtit:seśkeŕśtuŕan:sestiŕkatetin:seŕaikala:naltinke:bitutenin:iltuniŕaenai:bekoŕ:sebaketiŕan
# iunstir [['Verb', ['iunstir', 'i', 'unst', 'ir']]]
# salirk [['Sim Name', ['salir', 'salir', '', ' money']]]
# basirtir []
# sabaritai []
# birinar []
# kurs [['Name', ['kurs', 'kurs', '', ' unknown']]]
# boistinkistit []
# seskersturan []
# sestirkatetin []
# seraikala []
# naltinke []
# bitutenin []
# iltuniraenai [['Sim Personal Name', ['iltunirnai', 'iltunir', 'iltunir', 'iltun', 'ir', '', 'I am']], ['Sim Personal Name', ['iltunirtenai', 'iltunirte', 'iltunir', 'iltun', 'ir', 'ergative', 'I am']], ['Sim Personal Name', ['iltunirkanai', 'iltunirka', 'iltunir', 'iltun', 'ir', 'to recieve/give', 'I am']], ['Sim Personal Name', ['iltunirarnai', 'iltunirar', 'iltunir', 'iltun', 'ir', 'for/from', 'I am']], ['Sim Personal Name', ['iltunirennai', 'iltuniren', 'iltunir', 'iltun', 'ir', 'of', 'I am']], ['Sim Personal Name', ['iltunirentai', 'iltuniren', 'iltunir', 'iltun', 'ir', 'of', 'is/are']], ['Sim Personal Name', ['iltunirenai', 'iltuniren', 'iltunir', 'iltun', 'ir', 'of', 'are']], ['Sim Personal Name', ['iltunirenai', 'iltunire', 'iltunir', 'iltun', 'ir', 'for', 'I am']], ['Sim Personal Name', ['iltunireai', 'iltunire', 'iltunir', 'iltun', 'ir', 'for', 'are']], ['Sim Personal Name', ['iltunirkatenai', 'iltunirkate', 'iltunir', 'iltun', 'ir', '?', 'I am']]]
# bekor []
# sebaketiran []
# === iŕiseret
# iriseret []
# === ilaeŕi:isai
# ilaeri []
# isai []
# === kutu:leisi
# kutu [['Name', ['kutu', 'kutu', '', ' letter/document']]]
# leisi [['Sim Personal Name', ['leisir', 'leisir', 'leisir', 'leis', 'ir', '', '']], ['Sim Personal Name', ['leisai', 'leis', 'leis', 'leis', '', '', 'are']]]
# === _:leikta
# _ []
# leikta []
# === beri:leiŕia
# beri []
# leiria []
# === salir:iŕite:
# salir [['Name', ['salir', 'salir', '', ' money']]]
# irite []
#  []
# === setabeŕe:
# setabere []
#  []
# === _:arnai
# _ []
# arnai [['Verb', ['arnai', 'arn', 'ai', 'I am property of']]]
# === si____:
# si____ []
#  []
# === baitesir:biloskeŕe:biosiltun
# baitesir []
# biloskere [['Personal Name', ['biloskere', 'biloskere', 'bilosker', 'bilos', 'ker', 'for', '']], ['Personal Name', ['biloskere', 'biloskere', 'bilosker', 'bilos', 'sker', 'for', '']]]
# biosiltun [['Sim Personal Name', ['bilosiltun', 'bilosiltun', 'bilosiltun', 'bilos', 'iltun', '', '']], ['Sim Personal Name', ['bilosiltune', 'bilosiltune', 'bilosiltun', 'bilos', 'iltun', 'for', '']]]
# === iunteken:e__
# iunteken []
# e__ []
# === sakaŕbeś:sos__
# sakarbes [['Sim Personal Name', ['sakarbels', 'sakarbels', 'sakarbels', 'sakar', 'bels', '', '']]]
# sos__ []
# === lakutaś:kebes___
# lakutas [['Personal Name', ['lakutas', 'lakutas', 'lakutas', 'laku', 'tas', '', '']]]
# kebes___ []
# === iskenus:antinue___
# iskenus [['Sim Personal Name', ['iskenius', 'iskenius', 'iskenius', 'iske', 'nius', '', '']]]
# antinue___ []
# === taŕike:telbabinetitaŕke_s___ŕik
# tarike [['Sim Personal Name', ['tartike', 'tartiike', 'tarti', 'tarti', '', '?', '']]]
# telbabinetitarke_s___rik []
# === sabaŕbasteŕik:bitetenetesbesanelas:
# sabarbasterik []
# bitetenetesbesanelas []
#  []
# === ikbaite:suisebartaśaŕ:tituŕakunan
# ikbaite []
# suisebartasar []
# titurakunan []
# === nela:ebanalbasusbelikinela
# nela []
# ebanalbasusbelikinela []
# === _biantin:korsanlene:barer:beikulnaŕer:kanikbos
# _biantin []
# korsanlene []
# marer [['Sim Verb', ['umarer', '', 'umar', 'er']]]
# beikulnarer []
# kanikbos []
# === leitikeur
# leitikeur []
# === balkar
# balkar [['Sim Personal Name', ['balkear', 'balkear', 'balke', 'balke', '', 'for/from', '']]]
# === iltiŕtikeŕen
# iltirtikeren [['Personal Name', ['iltirtikeren', 'iltirtikeren', 'iltirtiker', 'iltir', 'tiker', 'of', '']]]
# === leis
# leis [['Personal Name', ['leis', 'leis', 'leis', 'leis', '', '', '']]]
# === ś
# s []
# === _ninaŕen
# _ninaren []
# === saka
# saka [['Personal Name', ['saka', 'saka', 'saka', 'saka', '', '', '']]]
